# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('../data/asia10K.csv')

# %%
dataset
# Out:
#      Smoker LungCancer VisitToAsia Tuberculosis TuberculosisOrCancer X-ray  \
# 0       yes        yes          no           no                  yes   yes
# 1        no         no          no           no                   no   yes
# 2        no         no          no           no                   no    no
# 3        no         no          no           no                   no    no
# 4       yes         no          no           no                   no    no
# ...     ...        ...         ...          ...                  ...   ...
# 9995     no         no          no           no                   no    no
# 9996     no         no          no           no                   no    no
# 9997     no         no          no           no                   no    no
# 9998     no         no          no           no                   no    no
# 9999    yes         no          no           no                   no    no
#
#      Bronchitis Dyspnea
# 0           yes     yes
# ...
